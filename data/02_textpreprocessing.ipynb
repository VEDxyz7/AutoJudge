# %%
import pandas as pd
df=pd.read_csv("/Users/vedparikh/Desktop/AutoJudge/data/problems_data.csv")
df.head()
text_cols=["title","description","input_description","output_description","sample_io"]
df[text_cols]=df[text_cols].fillna("") #which handles missing values
df["combined_text"]=(
    df["title"] + " " +
    df["description"] + " " +
    df["input_description"] + " " + 
    df["output_description"] + " " + 
    df["sample_io"]
)
df["combined_text"].head()
df["combined_text"].str.len().describe()
df.to_csv("/Users/vedparikh/Desktop/AutoJudge/data/problems_preprocessed.csv",index=False)
