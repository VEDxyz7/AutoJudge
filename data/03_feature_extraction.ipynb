# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack
import joblib

df=pd.read_csv("/Users/vedparikh/Desktop/AutoJudge/data/problems_preprocessed.csv")
df.head()
df["combined_text"].head()
df["text_length"]=df["combined_text"].str.len()
df["text_length"].describe()
keywords=["dp","graph","tree","recursion","binary","greedy","dfs","bfs"]
for i in keywords:
    df[f"kw_{i}"]=df["combined_text"].str.lower().str.count(i)
df["kw_greedy"].head()

tfidf=TfidfVectorizer(max_features=5000 , stop_words="english")
X_tfidf=tfidf.fit_transform(df["combined_text"])

numeric_features=df[["text_length"]+[f"kw_{i}" for i in keywords]]
X=hstack([X_tfidf,numeric_features.values])
numeric_features.head()

joblib.dump(tfidf, "/Users/vedparikh/Desktop/AutoJudge/models/tfidf_vectorizer.pkl")
# Out:
# ['/Users/vedparikh/Desktop/AutoJudge/models/tfidf_vectorizer.pkl']
