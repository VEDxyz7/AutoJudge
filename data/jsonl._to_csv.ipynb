# %%
import pandas as pd
import json

file_path = "/Users/vedparikh/Desktop/AutoJudge/data/problems_data.jsonl"
rows=[]
with open(file_path,"r",encoding='utf-8') as f:
    for line in f:
        rows.append(json.loads(line))
df=pd.DataFrame(rows)
df.to_csv("/Users/vedparikh/Desktop/AutoJudge/data/problems_data.csv",index=False)
# Out:
# Index(['title', 'description', 'input_description', 'output_description',
#        'sample_io', 'problem_class', 'problem_score', 'url'],
#       dtype='object')
